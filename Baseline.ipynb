# %%
import pandas as pd

# %%
Data = 'Data/ratings.csv'

df = pd.read_csv(Data, sep=',')
pivoted_table = df.pivot_table(index='userId', columns='movieId', values='rating', aggfunc='mean')

# %%
pivoted_table.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 610 entries, 1 to 610
# Columns: 9724 entries, 1 to 193609
# dtypes: float64(9724)
# memory usage: 45.3 MB
